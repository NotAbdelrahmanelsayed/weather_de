# %%
import requests
import pandas as pd
from configparser import ConfigParser
# import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 25)
# Read the configuration
conf = ConfigParser()
conf.read("configuration.conf")
data_dir = conf.get("visual_crossing", "path")

# %%
df = pd.read_csv(data_dir+"weather.csv")
to_drop = []

# %%
df.head()
# Out:
#   name             datetime  temp feelslike  dew humidity precip precipprob  \
# 0  مصر  2025-02-14T00:00:00  11.0      11.0  4.0     62.0    0.0        0.0
# 1  مصر  2025-02-14T01:00:00  11.0      11.0  4.0     62.0    0.0        0.0
# 2  مصر  2025-02-14T02:00:00  10.0       9.6  4.0    66.28    0.0        0.0
# 3  مصر  2025-02-14T03:00:00  10.0       9.1  4.0    66.28    0.0        0.0
# 4  مصر  2025-02-14T04:00:00  10.0      10.0  3.0    61.77    0.0        0.0
#
#   preciptype snow snowdepth windgust windspeed winddir sealevelpressure  \
# 0        NaN    0         0     16.2       5.4    90.0           1024.0
# 1        NaN    0         0     12.6       5.4    90.0           1023.0
# 2        NaN    0         0      9.7       5.4    80.0           1022.0
# 3        NaN    0         0     10.1       7.6    80.0           1022.0
# 4        NaN    0         0      9.7       3.6    90.0           1022.0
#
#   cloudcover visibility solarradiation solarenergy uvindex severerisk  \
# ...

# %%
df["conditions"].value_counts()
# Out:
# conditions
# Clear               1065
# Partially cloudy     595
# Overcast             140
# conditions             2
# Name: count, dtype: int64

# %%
df["stations"].value_counts()
# Out:
# stations
# HECA        90
# stations     2
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# name                   0
# datetime               0
# temp                   0
# feelslike              0
# dew                    0
# humidity               0
# precip                 0
# precipprob             0
# preciptype          1775
# snow                   0
# snowdepth              0
# windgust               0
# windspeed              0
# winddir                0
# sealevelpressure       0
# cloudcover             0
# visibility             0
# solarradiation         0
# solarenergy            0
# uvindex                0
# severerisk             0
# conditions             0
# icon                   0
# stations            1710
# dtype: int64

# %%
to_drop.append("preciptype")
to_drop.append("stations")
df.drop(columns=["stations", "preciptype"], inplace=True)

# %%
df.head(3)
# Out:
#   name             datetime  temp feelslike  dew humidity precip precipprob  \
# 0  مصر  2025-02-14T00:00:00  11.0      11.0  4.0     62.0    0.0        0.0
# 1  مصر  2025-02-14T01:00:00  11.0      11.0  4.0     62.0    0.0        0.0
# 2  مصر  2025-02-14T02:00:00  10.0       9.6  4.0    66.28    0.0        0.0
#
#   snow snowdepth windgust windspeed winddir sealevelpressure cloudcover  \
# 0    0         0     16.2       5.4    90.0           1024.0        0.0
# 1    0         0     12.6       5.4    90.0           1023.0       56.0
# 2    0         0      9.7       5.4    80.0           1022.0       10.6
#
#   visibility solarradiation solarenergy uvindex severerisk        conditions  \
# 0        6.0            0.0         0.0       0         10             Clear
# 1       10.0            0.0         0.0       0         10  Partially cloudy
# 2       10.0            0.0         0.0       0         10             Clear
#
#                   icon
# 0          clear-night
# ...

# %%
df.dtypes
# Out:
# name                object
# datetime            object
# temp                object
# feelslike           object
# dew                 object
# humidity            object
# precip              object
# precipprob          object
# snow                object
# snowdepth           object
# windgust            object
# windspeed           object
# winddir             object
# sealevelpressure    object
# cloudcover          object
# visibility          object
# solarradiation      object
# solarenergy         object
# uvindex             object
# severerisk          object
# conditions          object
# icon                object
# dtype: object

# %%
df["datetime"] = pd.to_datetime(df["datetime"], errors="coerce")
